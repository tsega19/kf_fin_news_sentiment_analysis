# %% [markdown]
# **Quantitative analysis using pynance and TaLib**

# %%
# import library
from scripts.stock_analysis import *

# %%
filepath = 'AAPL_historical_data.csv'
data = load_stock_data(filepath)
data.head()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6841  2024-07-24  183.199997  185.449997  180.410004  180.830002  180.830002
# 6842  2024-07-25  182.910004  183.899994  176.800003  179.850006  179.850006
# 6843  2024-07-26  180.389999  183.190002  180.240005  182.500000  182.500000
# 6844  2024-07-29  183.839996  184.750000  182.380005  183.199997  183.199997
# 6845  2024-07-30  184.720001  185.860001  179.380005  181.710007  181.710007
#
#           Volume  Dividends  Stock Splits
# 0     1443120000        0.0           0.0
# 1      294000000        0.0           0.0
# 2      122136000        0.0           0.0
# 3      109344000        0.0           0.0
# 4      377064000        0.0           0.0
# ...          ...        ...           ...
# 6841    41532400        0.0           0.0
# 6842    44464200        0.0           0.0
# 6843    29506000        0.0           0.0
# 6844    33270100        0.0           0.0
# 6845    39508600        0.0           0.0
#
# [6846 rows x 9 columns]

# %%
# Apply Technical Analysis Indicators with pandas_ta
data = apply_technical_indicators(data)
data.head()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6841  2024-07-24  183.199997  185.449997  180.410004  180.830002  180.830002
# 6842  2024-07-25  182.910004  183.899994  176.800003  179.850006  179.850006
# 6843  2024-07-26  180.389999  183.190002  180.240005  182.500000  182.500000
# 6844  2024-07-29  183.839996  184.750000  182.380005  183.199997  183.199997
# 6845  2024-07-30  184.720001  185.860001  179.380005  181.710007  181.710007
#
#           Volume  Dividends  Stock Splits     ADX_14     DMP_14     DMN_14  \
# 0     1443120000        0.0           0.0        NaN        NaN        NaN
# 1      294000000        0.0           0.0        NaN        NaN        NaN
# 2      122136000        0.0           0.0        NaN        NaN        NaN
# 3      109344000        0.0           0.0        NaN        NaN        NaN
# 4      377064000        0.0           0.0        NaN        NaN        NaN
# ...          ...        ...           ...        ...        ...        ...
# 6841    41532400        0.0           0.0  26.846765  17.301913  28.572813
# 6842    44464200        0.0           0.0  27.294543  15.513333  30.875208
# 6843    29506000        0.0           0.0  27.710338  14.741322  29.338724
# 6844    33270100        0.0           0.0  27.585513  16.612689  28.263902
# 6845    39508600        0.0           0.0  27.999183  14.995139  30.019689
#
#         stoch_k    stoch_d      macd  macd_signal  macd_hist        rsi
# 0           NaN        NaN       NaN          NaN        NaN        NaN
# 1           NaN        NaN       NaN          NaN        NaN        NaN
# 2           NaN        NaN       NaN          NaN        NaN        NaN
# 3           NaN        NaN       NaN          NaN        NaN        NaN
# 4           NaN        NaN       NaN          NaN        NaN        NaN
# ...         ...        ...       ...          ...        ...        ...
# 6841  14.951807  15.350130 -1.342010    -1.977124   0.635114  37.221397
# 6842  15.261986  16.266940 -1.878483    -2.010878   0.132395  36.132394
# 6843  13.297917  14.503904 -2.065994    -1.758711  -0.307283  41.146719
# 6844  21.249544  16.603149 -2.133520    -1.460990  -0.672530  42.432437
# 6845  24.056318  19.534593 -2.280971    -1.286753  -0.994218  40.408843
#
# [6846 rows x 18 columns]

# %%
# Calculate financial metrics
data = calculate_financial_metrics(data)
data.head()
# Out:
# Sharpe Ratio (Annualized): 0.7332506315915072
#
# Data with Financial Metrics:
#          Date      Open      High       Low     Close  Adj Close      Volume  \
# 0  1997-05-15  0.121875  0.125000  0.096354  0.097917   0.097917  1443120000
# 1  1997-05-16  0.098438  0.098958  0.085417  0.086458   0.086458   294000000
# 2  1997-05-19  0.088021  0.088542  0.081250  0.085417   0.085417   122136000
# 3  1997-05-20  0.086458  0.087500  0.081771  0.081771   0.081771   109344000
# 4  1997-05-21  0.081771  0.082292  0.068750  0.071354   0.071354   377064000
#
#    Dividends  Stock Splits  ADX_14  ...  DMN_14  stoch_k  stoch_d  macd  \
# 0        0.0           0.0     NaN  ...     NaN      NaN      NaN   NaN
# 1        0.0           0.0     NaN  ...     NaN      NaN      NaN   NaN
# 2        0.0           0.0     NaN  ...     NaN      NaN      NaN   NaN
# 3        0.0           0.0     NaN  ...     NaN      NaN      NaN   NaN
# 4        0.0           0.0     NaN  ...     NaN      NaN      NaN   NaN
#
#    macd_signal  macd_hist  rsi  daily_return  cumulative_return  volatility
# 0          NaN        NaN  NaN           NaN                NaN         NaN
# 1          NaN        NaN  NaN     -0.117028           0.882972         NaN
# 2          NaN        NaN  NaN     -0.012040           0.872341         NaN
# 3          NaN        NaN  NaN     -0.042685           0.835105         NaN
# 4          NaN        NaN  NaN     -0.127392           0.728719         NaN
#
# [5 rows x 21 columns]

# %%
# Plot stock prices with moving averages
plot_stock_prices(data)

# %%
# Plot stock prices with moving averages
plot_stock_prices(data)

# %%
#Plot MACD
plot_macd(data)

# %%
# Daily Returns and Cumulative Returns
plot_returns(data

# %%
# Plot volatility
plot_volatility(data)
